# %%
import pandas as pd
import numpy as np

# %%
lookup = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_us_ag_exports.csv')
rawdata = pd.read_csv('./shootings2016to2017.csv')

# %%
lookup.head()
# Out:
#   code        state category  total exports   beef  pork  poultry   dairy  \
# 0   AL      Alabama    state        1390.63   34.4  10.6    481.0    4.06
# 1   AK       Alaska    state          13.31    0.2   0.1      0.0    0.19
# 2   AZ      Arizona    state        1463.17   71.3  17.9      0.0  105.48
# 3   AR     Arkansas    state        3586.02   53.2  29.4    562.9    3.53
# 4   CA   California    state       16472.88  228.7  11.1    225.4  929.95
#
#    fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 0           8.0         17.1         25.11            5.5           8.9
# 1           0.0          0.0          0.00            0.6           1.0
# 2          19.3         41.0         60.27          147.5         239.4
# 3           2.2          4.7          6.88            4.4           7.1
# 4        2791.8       5944.6       8736.40          803.2        1303.5
#
#    total veggies  corn  wheat   cotton
# 0          14.33  34.9   70.0   317.61
# ...

# %%
rawdata.head()
# Out:
#        Incident Date       State City Or County                    Address  \
# 0  November 16, 2017     Georgia       Columbus  1400 block of 15th Street
# 1  November 14, 2017  California        Corning        17357 Stagecoach Rd
# 2  November 14, 2017  California       Richmond       900 Block of View Dr
# 3  November 12, 2017     Indiana           Gary             4601 Melton Rd
# 4  November 12, 2017  California         Fresno               S Calvin Ave
#
#    Killed  Injured  Operations
# 0       0        7         NaN
# 1       6       12         NaN
# 2       2        2         NaN
# 3       0        7         NaN
# 4       0        5         NaN

# %%
key = lookup[['state', 'code']]

# %%
rawdata.merge(key, left_on='State', right_on='state')
# Out:
#           Incident Date          State  \
# 0     November 16, 2017        Georgia
# 1     November 12, 2017        Georgia
# 2          July 5, 2017        Georgia
# 3         June 22, 2017        Georgia
# 4        April 13, 2017        Georgia
# 5         March 5, 2017        Georgia
# 6      January 26, 2017        Georgia
# 7      January 22, 2017        Georgia
# 8      January 21, 2017        Georgia
# 9     December 31, 2016        Georgia
# 10    December 28, 2016        Georgia
# 11     October 27, 2016        Georgia
# 12      August 30, 2016        Georgia
# 13       August 3, 2016        Georgia
# 14        July 30, 2016        Georgia
# 15        July 29, 2016        Georgia
# 16    November 12, 2017        Indiana
# 17     October 31, 2017        Indiana
# 18   September 20, 2017        Indiana
# 19      August 27, 2017        Indiana
# 20       April 15, 2017        Indiana
# 21        April 9, 2017        Indiana
# 22    February 26, 2017        Indiana
# ...

# %%
s = lookup.set_index('state')['code']
s.index = s.index.str.strip(' ')
s.head()
# Out:
# state
# Alabama       AL
# Alaska        AK
# Arizona       AZ
# Arkansas      AR
# California    CA
# Name: code, dtype: object

# %%
m = rawdata['State'].map(s)
m.value_counts(dropna=False)
# Out:
# CA     60
# IL     56
# TX     37
# FL     37
# OH     24
# NY     23
# PA     20
# TN     17
# LA     17
# NJ     17
# VA     16
# GA     16
# MO     16
# NC     14
# MS     13
# MD     13
# IN     12
# AL     11
# SC      9
# MI      9
# CT      7
# WA      6
# NaN     6
# KY      6
# AR      5
# MN      5
# AZ      5
# NM      4
# KS      4
# WI      3
# CO      2
# OK      2
# IA      2
# ME      1
# MA      1
# UT      1
# MT      1
# DE      1
# NV      1
# Name: State, dtype: int64

# %%
rawdata[m.isnull()]
# Out:
#           Incident Date                 State City Or County  \
# 103      August 3, 2017  District of Columbia     Washington
# 146       June 25, 2017  District of Columbia     Washington
# 153       June 18, 2017  District of Columbia     Washington
# 185        May 27, 2017  District of Columbia     Washington
# 289    January 31, 2017  District of Columbia     Washington
# 426  September 17, 2016  District of Columbia     Washington
#
#                                      Address  Killed  Injured  Operations
# 103                          3426 18th St NE       1        3         NaN
# 146            5900 block of Southern Ave SE       0        4         NaN
# 153     3100 block of Buena Vista Terrace SE       0        4         NaN
# 185          100 block of Q Street Northwest       1        7         NaN
# 289  2900 block of Martin Luther King Jr Ave       0        4         NaN
# 426            2600 block of Birney Place SE       2        7         NaN
