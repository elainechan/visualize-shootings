# %%
import pandas as pd
import numpy as np
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.plotly as py

#plotly.tools.set_credentials_file(username='chanechan', api_key='ijM1onyyvmTktWH4YLUg')

# %%
lookup = pd.read_csv('https://raw.githubusercontent.com/jasonong/List-of-US-States/master/states.csv')
rawdata = pd.read_csv('./shootings2016to2017.csv')

# %%
lookup.head()
# Out:
#         State Abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
rawdata.head()
rawdata
# Out:
#          Incident Date           State            City Or County  \
# 0    November 16, 2017         Georgia                  Columbus
# 1    November 14, 2017      California                   Corning
# 2    November 14, 2017      California                  Richmond
# 3    November 12, 2017         Indiana                      Gary
# 4    November 12, 2017      California                    Fresno
# 5    November 12, 2017         Georgia                   Atlanta
# 6    November 11, 2017           Texas                    Dallas
# 7    November 11, 2017       Louisiana               New Orleans
# 8    November 11, 2017  North Carolina              Fayetteville
# 9    November 10, 2017            Ohio         Dayton (Trotwood)
# 10    November 9, 2017    Pennsylvania              Philadelphia
# 11    November 5, 2017           Texas        Sutherland Springs
# 12    November 4, 2017           Texas                    Austin
# 13    November 4, 2017            Ohio                Youngstown
# 14    November 4, 2017      California              Santa Monica
# 15    November 3, 2017       Minnesota               Minneapolis
# 16    November 3, 2017      California                   Gardena
# 17    November 3, 2017        New York                   Buffalo
# 18    November 3, 2017       Louisiana                   Lacombe
# 19    October 31, 2017         Indiana                   Hammond
# 20    October 29, 2017           Texas                    Austin
# 21    October 28, 2017            Ohio                    Toledo
# 22    October 28, 2017        Virginia                Petersburg
# 23    October 27, 2017        Kentucky                Louisville
# 24    October 27, 2017      California             San Francisco
# 25    October 23, 2017      California            Clearlake Oaks
# 26    October 22, 2017     Connecticut                  Hartford
# 27    October 22, 2017         Alabama                    Lanett
# 28    October 21, 2017         Florida              Jacksonville
# 29    October 21, 2017       Tennessee                 Nashville
# ..                 ...             ...                       ...
# 470    August 12, 2016           Texas                    Dallas
# 471    August 11, 2016    Pennsylvania              Philadelphia
# 472    August 10, 2016        Illinois                  Evanston
# 473    August 10, 2016      California                Sacramento
# 474     August 8, 2016      New Mexico               Albuquerque
# 475     August 8, 2016         Florida              Jacksonville
# 476     August 7, 2016      California               Los Angeles
# 477     August 7, 2016     Mississippi                 Vicksburg
# 478     August 7, 2016        Colorado                    Arvada
# 479     August 7, 2016        Illinois                   Chicago
# 480     August 6, 2016    Pennsylvania  Reading (Sinking Spring)
# 481     August 5, 2016        Michigan                   Pontiac
# 482     August 5, 2016      California                    Perris
# 483     August 4, 2016       Tennessee                   Memphis
# 484     August 3, 2016         Georgia                   Decatur
# 485     August 2, 2016         Florida     Hollywood (West Park)
# 486     August 1, 2016         Indiana                Evansville
# 487      July 31, 2016         Florida                     Miami
# 488      July 31, 2016           Texas                    Austin
# 489      July 30, 2016        Missouri               Saint Louis
# 490      July 30, 2016         Georgia        Townsend (Eulonia)
# 491      July 30, 2016      Washington                  Mukilteo
# 492      July 29, 2016         Georgia                    Athens
# 493      July 28, 2016        New York                    Elmira
# 494      July 28, 2016        Maryland                 Baltimore
# 495      July 28, 2016        Illinois                   Chicago
# 496      July 25, 2016         Florida                Fort Myers
# 497      July 24, 2016            Ohio                  Hamilton
# 498      July 23, 2016  South Carolina          North Charleston
# 499      July 23, 2016        New York                  Brooklyn
#
#                                       Address  Killed  Injured  Operations
# 0                   1400 block of 15th Street       0        7         NaN
# 1                         17357 Stagecoach Rd       6       12         NaN
# 2                        900 Block of View Dr       2        2         NaN
# 3                              4601 Melton Rd       0        7         NaN
# 4                                S Calvin Ave       0        5         NaN
# 5                         50 Lower Alabama St       2        2         NaN
# 6             2532 Martin Luther King Jr Blvd       1        3         NaN
# 7         Forstall Street and Burgundy Street       1        5         NaN
# 8                             2835 Bragg Blvd       1        5         NaN
# 9                                193 Olive Rd       0        4         NaN
# 10                     1800 block of Ringgold       0        4         NaN
# 11                                 216 4th St      27       20         NaN
# 12            N Lamar Blvd and Masterson Pass       0        4         NaN
# 13                             2810 Market St       0        4         NaN
# 14                          1515 Ocean Avenue       1        3         NaN
# 15                   10th Ave S and E 24th St       0        4         NaN
# 16                   E 163rd St and S Main St       0        4         NaN
# 17                          147 Roosevelt Ave       0        4         NaN
# 18               27600 block of Mirmar Street       1        4         NaN
# 19                     500 block of Pointe Dr       1        3         NaN
# 20                        5500 block of Ave F       1        3         NaN
# 21                            1327 N Huron St       0        4         NaN
# 22                 N Sycamore St and Franklin       1        3         NaN
# 23                           1716 Prentice St       0        6         NaN
# 24                     1100 block of Fillmore       0        4         NaN
# 25              13000 block of Anchor Village       2        2         NaN
# 26     Wethersfield Avenue and Elliott Street       0        4         NaN
# 27                            1606 19th St Sw       2        7         NaN
# 28                           164 E Eubanks St       0        4         NaN
# 29                            1277 12th Ave S       0        4         NaN
# ..                                        ...     ...      ...         ...
# 470                           10921 Estate Ln       1        3         NaN
# 471                 500 block of E Ashmead St       0        4         NaN
# 472          Foster Street and Jackson Avenue       0        4         NaN
# 473                     4000 Green Tree Drive       1        3         NaN
# 474            341 General Marshall Street NE       2        2         NaN
# 475                           1214 Labelle St       0        7         NaN
# 476                5925 South Figueroa Street       1        3         NaN
# 477                              4460 Clay St       1        3         NaN
# 478          5400 block of Sheridan Boulevard       2        2         NaN
# 479            100 block of South Springfield       0        4         NaN
# 480                    51 Winding Brook Drive       5        0         NaN
# 481                 70 block of Thorpe Street       1        3         NaN
# 482                   21600 block of Rider St       2        2         NaN
# 483          Ayers Street and Griffith Avenue       0        4         NaN
# 484                        4110 Glenwood Road       1        3         NaN
# 485       5700 block of Hallandale Beach Blvd       0        4         NaN
# 486                      South Bedford Avenue       0        4         NaN
# 487  Southwest 203rd Terrace and 115th Avenue       3        1         NaN
# 488                              208 E 6th St       1        4         NaN
# 489              5000 block of Kensington Ave       0        5         NaN
# 490                          14699 Highway 17       0        5         NaN
# 491                     10009 Chennault Beach       3        1         NaN
# 492                            Trail Creek St       0        7         NaN
# 493                           303 College Ave       0        5         NaN
# 494                         Greenmount Avenue       0        4         NaN
# 495              800 block of West 50th Place       2        2         NaN
# 496                            3580 Evans Ave       2       19         NaN
# 497                              1555 Main St       1        7         NaN
# 498                3630 Ashley Phosphate Road       0        4         NaN
# 499                           Fountain Avenue       0        4         NaN
#
# [500 rows x 7 columns]

# %%
key = lookup[['State', 'Abbreviation']]

# %%
rawdata.merge(key, left_on='State', right_on='Abbreviation')
# Out:
# Empty DataFrame
# Columns: [Incident Date, State_x, City Or County, Address, Killed, Injured, Operations, State_y, Abbreviation]
# Index: []

# %%
s = lookup.set_index('State')['Abbreviation']
s.index = s.index.str.strip(' ')
s.head()
# Out:
# State
# Alabama       AL
# Alaska        AK
# Arizona       AZ
# Arkansas      AR
# California    CA
# Name: Abbreviation, dtype: object

# %%
m = rawdata['State'].map(s)
m.to_frame

incidents = m.value_counts(dropna=False)

# %%
m.head()
# Out:
# 0    GA
# 1    CA
# 2    CA
# 3    IN
# 4    CA
# Name: State, dtype: object

# %%
pd.DataFrame(incidents)
# Out:
#     State
# CA     60
# IL     56
# TX     37
# FL     37
# OH     24
# NY     23
# PA     20
# TN     17
# NJ     17
# LA     17
# VA     16
# MO     16
# GA     16
# NC     14
# MD     13
# MS     13
# IN     12
# AL     11
# MI      9
# SC      9
# CT      7
# KY      6
# WA      6
# DC      6
# MN      5
# AR      5
# AZ      5
# NM      4
# KS      4
# WI      3
# OK      2
# IA      2
# CO      2
# ME      1
# DE      1
# NV      1
# MA      1
# MT      1
# UT      1

# %%
incidents.index
# Out:
# Index(['CA', 'IL', 'TX', 'FL', 'OH', 'NY', 'PA', 'TN', 'NJ', 'LA', 'VA', 'MO',
#        'GA', 'NC', 'MD', 'MS', 'IN', 'AL', 'MI', 'SC', 'CT', 'KY', 'WA', 'DC',
#        'MN', 'AR', 'AZ', 'NM', 'KS', 'WI', 'OK', 'IA', 'CO', 'ME', 'DE', 'NV',
#        'MA', 'MT', 'UT'],
#       dtype='object')

# %%
incidents = pd.DataFrame(incidents)
incidents.rename(index=str, columns={ 0 : 'Incidents'})
incidents_index = pd.DataFrame(incidents.index)
type(incidents_index)
incidents_index
# Out:
#      0
# 0   CA
# 1   IL
# 2   TX
# 3   FL
# 4   OH
# 5   NY
# 6   PA
# 7   TN
# 8   NJ
# 9   LA
# 10  VA
# 11  MO
# 12  GA
# 13  NC
# 14  MD
# 15  MS
# 16  IN
# 17  AL
# 18  MI
# 19  SC
# 20  CT
# 21  KY
# 22  WA
# 23  DC
# 24  MN
# 25  AR
# 26  AZ
# 27  NM
# 28  KS
# 29  WI
# 30  OK
# 31  IA
# 32  CO
# 33  ME
# 34  DE
# 35  NV
# 36  MA
# 37  MT
# 38  UT

# %%
ndf = pd.DataFrame()
ndf['State'] = incidents_index
ndf['Incidents'] = incidents

ndf

>>> d = {'col1': [1, 2], 'col2': [3, 4]}
>>> df = pd.DataFrame(data=d)

d = { 'State': incidents_index, 'Incidents' }
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     398                 result = np.empty(len(values), dtype=object)
# --> 399                 result[:] = values
#     400             except ValueError:
#
# ValueError: could not broadcast input array from shape (39,1) into shape (39)
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    2563             try:
# -> 2564                 value = Series(value)
#    2565             except:
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     263                 data = _sanitize_array(data, index, dtype, copy,
# --> 264                                        raise_cast_failure=True)
#     265
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    3235         else:
# -> 3236             subarr = _asarray_tuplesafe(data, dtype=dtype)
#    3237
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     401                 # we have a list-of-list
# --> 402                 result[:] = [tuple(x) for x in values]
#     403
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/common.py in <listcomp>(.0)
#     401                 # we have a list-of-list
# --> 402                 result[:] = [tuple(x) for x in values]
#     403
#
# TypeError: 'int' object is not iterable
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-597220df89c0> in <module>()
#       1 ndf = pd.DataFrame()
# ----> 2 ndf['State'] = incidents_index
#       3 ndf['Incidents'] = incidents
#       4
#       5 ndf
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2582         """
#    2583
# -> 2584         self._ensure_valid_index(value)
#    2585         value = self._sanitize_column(key, value)
#    2586         NDFrame._set_item(self, key, value)
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    2564                 value = Series(value)
#    2565             except:
# -> 2566                 raise ValueError('Cannot set a frame with no defined index '
#    2567                                  'and a value that cannot be converted to a '
#    2568                                  'Series')
#
# ValueError: Cannot set a frame with no defined index and a value that cannot be converted to a Series

# %%
# viridis
brew = ["#ffffd9","#edf8b1","#c7e9b4","#7fcdbb","#41b6c4","#1d91c0","#225ea8","#253494","#081d58"]
# plotly colorscale format
scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

# %%
data = [ dict(
        type='choropleth',
        colorscale = 'Viridis',
        autocolorscale = False,
        locations = incidents.index,
        z = incidents['State'].astype(int),
        locationmode = 'USA-states',
        # text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Number of Mass Shootings in the United States From July 23, 2016 to November 16, 2017")
        ) ]

# %%
layout = dict(
        title = '',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='mass-shootings-incidents-choropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~chanechan/2.embed" height="525px" width="100%"></iframe>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_us_ag_exports.csv')

# %%
type(df['code'])
# Out:
# pandas.core.series.Series
